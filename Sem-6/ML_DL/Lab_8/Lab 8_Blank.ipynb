# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>ML & DL</b></center>
#
# <center><b><h1>Lab - 9</b></center>
# <pre>

# %% [markdown]
# # Step 1: Import Libraries
# This step imports all necessary libraries for data processing, visualization, and machine learning.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2: Load the Dataset
# Load Given dataset -  heart.csv

# %%
df = pd.read_csv("heart.csv")

# %% [markdown]
# # Step 3: Data Overview
# In this step, we examine the dataset structure, summary statistics, and check for missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %% [markdown]
# # Step 4: Univariate Analysis
# Here we visualize the distribution of each feature using histograms.

# %%
df.hist(figsize=(12,12))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # Step 5: Bivariate Analysis
# This step involves exploring the correlations between features using a heatmap.

# %%
import seaborn as sns

# %%
# %matplotlib qt

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Step 6: Outlier Detection
# We visualize potential outliers using boxplots.

# %%
df.boxplot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.boxplot()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:533, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)    530     **kwargs,
#     531 ):
#     532     plot_backend = _get_plot_backend(backend)
# --> 533     return plot_backend.boxplot_frame(
#     534         self,
#     535         column=column,
#     536         by=by,
#     537         ax=ax,
#     538         fontsize=fontsize,
#     539         rot=rot,
#     540         grid=grid,
#     541         figsize=figsize,
#     542         layout=layout,
#     543         return_type=return_type,
#     544         **kwargs,
#     545     )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:495, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     480 def boxplot_frame(
#     481     self,
#     482     column=None,
#    (...)    491     **kwds,
#     492 ):
#     493     import matplotlib.pyplot as plt
# --> 495     ax = boxplot(
#     496         self,
#     497         column=column,
#     498         by=by,
#     499         ax=ax,
#     500         fontsize=fontsize,
#     501         grid=grid,
#     502         rot=rot,
#     503         figsize=figsize,
#     504         layout=layout,
#     505         return_type=return_type,
#     506         **kwds,
#     507     )
#     508     plt.draw_if_interactive()
#     509     return ax
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:474, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     471     else:
#     472         data = data[columns]
# --> 474     result = plot_group(columns, data.values.T, ax, **kwds)
#     475     ax.grid(grid)
#     477 return result
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:417, in boxplot.<locals>.plot_group(keys, values, ax, **kwds)
#     414     ax.tick_params(axis="both", labelsize=fontsize)
#     416 # GH 45465: x/y are flipped when "vert" changes
# --> 417 _set_ticklabels(
#     418     ax=ax, labels=keys, is_vertical=kwds.get("vert", True), rotation=rot
#     419 )
#     420 maybe_color_bp(bp, color_tup=colors, **kwds)
#     422 # Return axes in multiplot case, maybe revisit later # 985
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_matplotlib\boxplot.py:63, in _set_ticklabels(ax, labels, is_vertical, **kwargs)
#      61     labels *= i
#      62 if is_vertical:
# ---> 63     ax.set_xticklabels(labels, **kwargs)
#      64 else:
#      65     ax.set_yticklabels(labels, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axis.py:2106, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2102 elif isinstance(locator, mticker.FixedLocator):
#    2103     # Passing [] as a list of labels is often used as a way to
#    2104     # remove all tick labels, so only error for > 0 labels
#    2105     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2106         raise ValueError(
#    2107             "The number of FixedLocator locations"
#    2108             f" ({len(locator.locs)}), usually from a call to"
#    2109             " set_ticks, does not match"
#    2110             f" the number of labels ({len(labels)}).")
#    2111     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2112     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (21), usually from a call to set_ticks, does not match the number of labels (14).

# %% [markdown]
# # Step 7: Split Data into Training and Testing Sets
# The dataset is split into training and testing sets for model evaluation.

# %%
x = df.iloc[::,:-1:]

# %%
y = df['target']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=80)

# %% [markdown]
# # Step 8: Train Decision Tree
# We train a Decision Tree Classifier on the training data. You have to also check for KNeighborsClassifier and  GaussianNB

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score

# %%
y_predict = model.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.9707792207792207

# %%
model.score(x_test,y_test)
# Out:
# 0.9707792207792207

# %% [markdown]
# # Step 11: Train Bagging Classifier
# We train a Bagging Classifier with Decision Trees as the base model.

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bc = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100)

# %%
bc.fit(x_train, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100)

# %%
y_predict = bc.predict(x_test)

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.9902597402597403

# %% [markdown]
# # Step 12: Evaluate Bagging Classifier
# The Bagging model is evaluated using accuracy.

# %%
accuracy_score(y_train, bc.predict(x_train))
# Out:
# 1.0

# %% [markdown]
# # Step 13: Train Random Forest
# We train a Random Forest Classifier on the dataset.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100, max_features='sqrt')

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = rfc.predict(x_test)

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.9902597402597403

# %%
accuracy_score(y_train, rfc.predict(x_train))
# Out:
# 1.0

# %% [markdown]
# # Step 14: Feature Importance in Random Forest
# We analyze feature importance as determined by the Random Forest model.

# %%
rfc.feature_importances_
# Out:
# array([0.09882767, 0.02878626, 0.11893539, 0.07409691, 0.07652107,
#        0.0092866 , 0.02332054, 0.11282885, 0.04796081, 0.12236153,
#        0.04296127, 0.14696229, 0.0971508 ])

# %%
rfc.feature_names_in_
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal'], dtype=object)

# %% [markdown]
# # Step 15: Evaluate Random Forest
# We evaluate the Random Forest model using accuracy.

# %%
dt = DecisionTreeClassifier(max_depth=1)

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
accuracy_score(y_test, dt.predict(x_test))
# Out:
# 0.7597402597402597

# %%
accuracy_score(y_train, dt.predict(x_train))
# Out:
# 0.7601115760111576

# %% [markdown]
# # Step 16: Train AdaBoost Classifier
# We train an AdaBoost Classifier on the dataset.

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
adbc = AdaBoostClassifier(n_estimators=100, estimator=DecisionTreeClassifier(max_depth=100))

# %%
adbc.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=100),
#                    n_estimators=100)

# %% [markdown]
# # Step 17: Evaluate AdaBoost Classifier
# The AdaBoost model is evaluated using accuracy.

# %%
y_predict = adbc.predict(x_test)

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.9707792207792207

# %%
accuracy_score(y_train, adbc.predict(x_train))
# Out:
# 1.0

# %% [markdown]
# # <---- B ---->

# %% [markdown]
# ## Cost Complexity Pruning for Decision Tree

# %%
clf = DecisionTreeClassifier(random_state=42)
path = clf.cost_complexity_pruning_path(x_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=42, ccp_alpha=ccp_alpha)
    clf.fit(x_train, y_train)
    clfs.append(clf)

# %%
clfs = clfs[:-1]
ccp_alphas = ccp_alphas[:-1]

# %% [markdown]
# ## Random Forest with Iterative Training (OOB Error)

# %%
rf = RandomForestClassifier(oob_score=True, warm_start=True, random_state=42)

oob_error_rates = []
n_estimators_list = list(range(10, 201, 10))

for n in n_estimators_list:
    rf.set_params(n_estimators=n)
    rf.fit(x_train, y_train)
    
    # OOB Error = 1 - OOB Score
    oob_error = 1 - rf.oob_score_
    oob_error_rates.append(oob_error)
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\ensemble\_forest.py:611: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(

# %%
plt.figure(figsize=(10,6))
plt.plot(n_estimators_list, obb_error_rates, marker='0', linestyle='-')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 plt.plot(n_estimators_list, obb_error_rates, marker='0', linestyle='-')
#
# NameError: name 'obb_error_rates' is not defined

# %% [markdown]
# ## Receiver Operating Characteristic (ROC) Analysis

# %%
from sklearn.metrics import roc_curve, auc


y_prob = rf.predict_proba(x_test)[:, 1]

# Calculate ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
